# %%
# !pip install textract
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for textract: filename=textract-1.6.4-py3-none-any.whl size=22875 sha256=8b6ff5574317ce32c110a210339cab9f4bcc5d3a7e42193ac0ea82fd829a08ee
#   Stored in directory: c:\users\pc\appdata\local\pip\cache\wheels\0a\1f\84\cbcc7e7ac3797486650534ce9397f213e853e598243c90104c
# ...
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38162 sha256=6aa01880ee85d80b23f8c72ed18591b9ce42197102ea8d08e014e7908b9ae2f3
# ...

# %%
# !pip install extract_text
# Out:
# WARNING: Ignoring invalid distribution -pype1 (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pc\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement extract_text (from versions: none)
# ERROR: No matching distribution found for extract_text
# WARNING: Ignoring invalid distribution -pype1 (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pc\anaconda3\lib\site-packages)

# %%
import pdfplumber

with pdfplumber.open('드림비트 사업소득 원천징수영수증_page_186.pdf') as pdf:
    first_page = pdf.pages[0]
    a=first_page.extract_text()

    
    
for i in range(len(a)):
    if a[i]=='⑨':
        print(a[i+5:i+9])
# Out:
# 이윤주
